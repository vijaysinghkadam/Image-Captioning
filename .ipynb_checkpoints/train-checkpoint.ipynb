# %%
import argparse
import torch
import torch.nn as nn
import os
from torchvision import transforms
import pickle
from data_preprocess import get_loader
from model import EncoderCNN,DecoderRNN
from torch.nn.utils.rnn import pack_padded_sequence
from build_vocab import Vocabulary
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\manda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
device = ('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# 'cuda:0'

# %%
def main(args):
    #create model directory
    if not os.path.exists(args.model_path):
        os.makedirs(args.model_path)
    
    #image preprocessing and normalzation stuff(define transforms)
    transform = transforms.Compose([
        transforms.RandomCrop(args.crop_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.485,0.456,0.406),
                             (0.229,0.224,0.225)),
    ])
    
    
    #load vocabulary wrapper
    with open(args.vocab_path , 'rb') as f:
        vocab = pickle.load(f)


    #build data-loader
    data_loader = get_loader(args.image_dir , args.caption , vocab ,transform ,args.batch_size ,shuffle = True ,
                             num_workers = args.num_workers)
    
    #build the model
    encoder = EncoderCNN(args.embed_size).to(device)
    decoder = DecoderRNN(len(vocab) , args.embed_size , args.hidden_size , args.num_layers).to(device)
    
    #define loss and optimizer function
    criterion = nn.CrossEntropyLoss()
    params = list(decoder.parameters()) + list(encoder.linear.parameters()) + list(encoder.batch_norm.parameters())
    optimizer = torch.optim.Adam(params , lr = args.learning_rate)
    
    
    #train the model
    total_step = len(data_loader)
    for epoch in range(args.num_epochs):
        for i,(images,captions,lengths) in enumerate(data_loader):
            images = images.to(device)
            captions = captions.to(device)
            targets = pack_padded_sequence(captions , lengths ,batch_first=True)[0]
            
            #forward and backprop
            features = encoder(images)
            outputs = decoder(features,captions,lengths)
            
            loss = criterion(outputs , targets)
            decoder.zero_grad()
            encoder.zero_grad()
            
            loss.backward()
            optimizer.step()
            #print log info
            if i%args.log_step == 0:
                print('Epoch {}/{}  , Step {}/{}  , Loss {:.4f} , Perplexity{:5.4f}'.format(epoch,args.num_epochs,
                                                                                           i,total_step , loss.item(),
                                                                                           np.exp(loss.item())))
            
            #save the model
            if (i+1)%args.save_step == 0:
                torch.save(decoder.state_dict(),os.path.join(args.model_path, 'decoder-{}-{}.ckpt'.format(epoch+1,i+1)))
                torch.save(encoder.state_dict(),os.path.join(args.model_path, 'encoder-{}-{}.ckpt'.format(epoch+1,i+1)))

# %%
if __name__=='__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--model_path' , type=str , default='models/',help='path for saving models')
    parser.add_argument('--crop_size' , type=int , default= 224, help= 'crop size')
    parser.add_argument('--vocab_path', type=str, default='data/vocab.pkl' ,help = 'this is path for vocabulary wrapper')
    parser.add_argument('--image_dir',type =str, default='data/processed_images/' ,help = 'path for processed images')
    parser.add_argument('--caption' ,type=str, default='data/annotations/captions_train2014.json' ,help = 'path for train annotations')
    parser.add_argument('--batch_size' ,type=int ,default = 128)
    
    parser.add_argument('--embed_size', type =int ,default =256 ,help = 'dimension of word embedding vectors')
    parser.add_argument('--hidden_size',type = int ,default = 512 ,help = 'dimension of lstm hidden states')
    parser.add_argument('--num_layers', type = int , default = 1, help = 'number of layers of lstm')
    
    parser.add_argument('--learning_rate', type =float , default =0.001)
    parser.add_argument('--num_epochs' ,type = int , default = 5)
    parser.add_argument('--num_workers', type =int ,default =4)
    parser.add_argument('--log_step' ,type =int ,default = 10 ,help = 'step size for printing log info')
    parser.add_argument('--save_step',type =int ,default = 1000,help = 'step size for saving the model')
    args = parser.parse_args(args =[])
    print(args)
    main(args)
# Out:
# Namespace(batch_size=128, caption='data/annotations/captions_train2014.json', crop_size=224, embed_size=256, hidden_size=512, image_dir='data/processed_images/', learning_rate=0.001, log_step=10, model_path='models/', num_epochs=5, num_layers=1, num_workers=4, save_step=1000, vocab_path='data/vocab.pkl')
# loading annotations into memory...
# Done (t=2.73s)
# creating index...
# index created!
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to C:\Users\manda/.torch\models\resnet152-b121ed2d.pth
# 100.0%
# Epoch 0/5  , Step 0/3236  , Loss 9.2067 , Perplexity9963.3521
# Epoch 0/5  , Step 10/3236  , Loss 5.9100 , Perplexity368.7021
# Epoch 0/5  , Step 20/3236  , Loss 5.4377 , Perplexity229.9238
# Epoch 0/5  , Step 30/3236  , Loss 4.9734 , Perplexity144.5235
# Epoch 0/5  , Step 40/3236  , Loss 4.5520 , Perplexity94.8214
# Epoch 0/5  , Step 50/3236  , Loss 4.6409 , Perplexity103.6411
# Epoch 0/5  , Step 60/3236  , Loss 4.3414 , Perplexity76.8171
# Epoch 0/5  , Step 70/3236  , Loss 4.1295 , Perplexity62.1489
# Epoch 0/5  , Step 80/3236  , Loss 4.1163 , Perplexity61.3329
# Epoch 0/5  , Step 90/3236  , Loss 4.0430 , Perplexity56.9974
# Epoch 0/5  , Step 100/3236  , Loss 3.8160 , Perplexity45.4235
# Epoch 0/5  , Step 110/3236  , Loss 3.8374 , Perplexity46.4070
# Epoch 0/5  , Step 120/3236  , Loss 3.8711 , Perplexity47.9956
# Epoch 0/5  , Step 130/3236  , Loss 3.5995 , Perplexity36.5805
# Epoch 0/5  , Step 140/3236  , Loss 3.6755 , Perplexity39.4696
# Epoch 0/5  , Step 150/3236  , Loss 3.7865 , Perplexity44.1026
# Epoch 0/5  , Step 160/3236  , Loss 3.5998 , Perplexity36.5905
# Epoch 0/5  , Step 170/3236  , Loss 3.5658 , Perplexity35.3692
# Epoch 0/5  , Step 180/3236  , Loss 3.6665 , Perplexity39.1164
# Epoch 0/5  , Step 190/3236  , Loss 3.5058 , Perplexity33.3071
# Epoch 0/5  , Step 200/3236  , Loss 3.4759 , Perplexity32.3261
# Epoch 0/5  , Step 210/3236  , Loss 3.3135 , Perplexity27.4808
# Epoch 0/5  , Step 220/3236  , Loss 3.2816 , Perplexity26.6184
# Epoch 0/5  , Step 230/3236  , Loss 3.3609 , Perplexity28.8142
# Epoch 0/5  , Step 240/3236  , Loss 3.2774 , Perplexity26.5055
# Epoch 0/5  , Step 250/3236  , Loss 3.3543 , Perplexity28.6247
# Epoch 0/5  , Step 1360/3236  , Loss 2.4960 , Perplexity12.1344
# Epoch 0/5  , Step 1370/3236  , Loss 2.4555 , Perplexity11.6525
# Epoch 0/5  , Step 1380/3236  , Loss 2.3633 , Perplexity10.6264
# Epoch 0/5  , Step 1390/3236  , Loss 2.3760 , Perplexity10.7622
# Epoch 0/5  , Step 1400/3236  , Loss 2.5006 , Perplexity12.1893
# Epoch 0/5  , Step 1410/3236  , Loss 2.4937 , Perplexity12.1058
# Epoch 0/5  , Step 1420/3236  , Loss 2.4835 , Perplexity11.9829
# Epoch 0/5  , Step 1430/3236  , Loss 2.4955 , Perplexity12.1275
# Epoch 0/5  , Step 1440/3236  , Loss 2.5685 , Perplexity13.0459
# Epoch 0/5  , Step 1450/3236  , Loss 2.4623 , Perplexity11.7323
# Epoch 0/5  , Step 1460/3236  , Loss 2.3490 , Perplexity10.4749
# Epoch 0/5  , Step 1470/3236  , Loss 2.4117 , Perplexity11.1530
# Epoch 0/5  , Step 1480/3236  , Loss 2.3690 , Perplexity10.6867
# Epoch 0/5  , Step 1490/3236  , Loss 2.4686 , Perplexity11.8062
# Epoch 0/5  , Step 1500/3236  , Loss 2.3037 , Perplexity10.0111
# Epoch 0/5  , Step 1510/3236  , Loss 2.5582 , Perplexity12.9120
# Epoch 0/5  , Step 1520/3236  , Loss 2.4898 , Perplexity12.0588
# Epoch 0/5  , Step 1530/3236  , Loss 2.3495 , Perplexity10.4804
# Epoch 0/5  , Step 1540/3236  , Loss 2.4813 , Perplexity11.9564
# Epoch 0/5  , Step 1550/3236  , Loss 2.4839 , Perplexity11.9881
# Epoch 0/5  , Step 1560/3236  , Loss 2.5305 , Perplexity12.5602
# Epoch 0/5  , Step 1570/3236  , Loss 2.4351 , Perplexity11.4174
# Epoch 0/5  , Step 1580/3236  , Loss 2.4236 , Perplexity11.2860
# Epoch 0/5  , Step 1590/3236  , Loss 2.4648 , Perplexity11.7609
# Epoch 0/5  , Step 1600/3236  , Loss 2.2260 , Perplexity9.2630
# Epoch 0/5  , Step 1610/3236  , Loss 2.5011 , Perplexity12.1964
# Epoch 0/5  , Step 1620/3236  , Loss 2.4884 , Perplexity12.0414
# Epoch 0/5  , Step 1630/3236  , Loss 2.3528 , Perplexity10.5150
# Epoch 0/5  , Step 1640/3236  , Loss 2.4606 , Perplexity11.7121
# Epoch 0/5  , Step 1650/3236  , Loss 2.6099 , Perplexity13.5974
# Epoch 0/5  , Step 1660/3236  , Loss 2.4451 , Perplexity11.5314
# Epoch 0/5  , Step 1670/3236  , Loss 2.4938 , Perplexity12.1071
# Epoch 0/5  , Step 1680/3236  , Loss 2.3248 , Perplexity10.2243
# Epoch 0/5  , Step 1690/3236  , Loss 2.4441 , Perplexity11.5199
# Epoch 0/5  , Step 1700/3236  , Loss 2.6223 , Perplexity13.7672
# Epoch 0/5  , Step 1710/3236  , Loss 2.3189 , Perplexity10.1644
# Epoch 0/5  , Step 1720/3236  , Loss 2.4445 , Perplexity11.5246
# Epoch 0/5  , Step 1730/3236  , Loss 2.3108 , Perplexity10.0827
# Epoch 0/5  , Step 1740/3236  , Loss 2.4140 , Perplexity11.1787
# Epoch 0/5  , Step 1750/3236  , Loss 2.4497 , Perplexity11.5846
# Epoch 0/5  , Step 1760/3236  , Loss 2.4671 , Perplexity11.7885
# Epoch 0/5  , Step 1770/3236  , Loss 2.4762 , Perplexity11.8961
# Epoch 0/5  , Step 1780/3236  , Loss 2.4094 , Perplexity11.1276
# Epoch 0/5  , Step 1790/3236  , Loss 2.2793 , Perplexity9.7698
# Epoch 0/5  , Step 1800/3236  , Loss 2.3961 , Perplexity10.9798
# Epoch 0/5  , Step 1810/3236  , Loss 2.4679 , Perplexity11.7981
# Epoch 0/5  , Step 1820/3236  , Loss 2.4553 , Perplexity11.6505
# Epoch 0/5  , Step 1830/3236  , Loss 2.3605 , Perplexity10.5961
# Epoch 0/5  , Step 1840/3236  , Loss 2.2788 , Perplexity9.7654
# Epoch 0/5  , Step 1850/3236  , Loss 2.4529 , Perplexity11.6217
# Epoch 0/5  , Step 1860/3236  , Loss 2.4069 , Perplexity11.0993
# Epoch 0/5  , Step 1870/3236  , Loss 2.3476 , Perplexity10.4604
# Epoch 0/5  , Step 1880/3236  , Loss 2.4725 , Perplexity11.8516
# Epoch 0/5  , Step 1890/3236  , Loss 2.1915 , Perplexity8.9487
# Epoch 0/5  , Step 1900/3236  , Loss 2.3974 , Perplexity10.9943
# Epoch 0/5  , Step 1910/3236  , Loss 2.4581 , Perplexity11.6826
# Epoch 0/5  , Step 1920/3236  , Loss 2.3025 , Perplexity9.9991
# Epoch 0/5  , Step 1930/3236  , Loss 2.4276 , Perplexity11.3316
# Epoch 0/5  , Step 1940/3236  , Loss 2.4172 , Perplexity11.2141
# Epoch 0/5  , Step 1950/3236  , Loss 2.2865 , Perplexity9.8400
# Epoch 0/5  , Step 1960/3236  , Loss 2.4308 , Perplexity11.3682
# Epoch 0/5  , Step 1970/3236  , Loss 2.5437 , Perplexity12.7264
# Epoch 0/5  , Step 1980/3236  , Loss 2.2231 , Perplexity9.2357
# Epoch 0/5  , Step 1990/3236  , Loss 2.3889 , Perplexity10.9010
# Epoch 0/5  , Step 2000/3236  , Loss 2.4524 , Perplexity11.6162
# Epoch 0/5  , Step 2010/3236  , Loss 2.5227 , Perplexity12.4624
# Epoch 0/5  , Step 2020/3236  , Loss 2.4116 , Perplexity11.1520
# Epoch 0/5  , Step 2030/3236  , Loss 2.4530 , Perplexity11.6237
# Epoch 0/5  , Step 2040/3236  , Loss 2.3180 , Perplexity10.1557
# Epoch 0/5  , Step 2050/3236  , Loss 2.5056 , Perplexity12.2510
# Epoch 0/5  , Step 2060/3236  , Loss 2.4614 , Perplexity11.7210
# Epoch 0/5  , Step 2070/3236  , Loss 2.4127 , Perplexity11.1640
# Epoch 0/5  , Step 2080/3236  , Loss 2.3637 , Perplexity10.6303
# Epoch 0/5  , Step 2090/3236  , Loss 2.1717 , Perplexity8.7731
# Epoch 0/5  , Step 2100/3236  , Loss 2.3948 , Perplexity10.9663
# Epoch 0/5  , Step 2110/3236  , Loss 2.4113 , Perplexity11.1488
# Epoch 0/5  , Step 2120/3236  , Loss 2.4642 , Perplexity11.7535
# Epoch 0/5  , Step 2130/3236  , Loss 2.3417 , Perplexity10.3986
# Epoch 0/5  , Step 2140/3236  , Loss 2.3567 , Perplexity10.5557
# Epoch 0/5  , Step 2150/3236  , Loss 2.3727 , Perplexity10.7263
# Epoch 0/5  , Step 2160/3236  , Loss 2.2350 , Perplexity9.3469
# Epoch 0/5  , Step 2170/3236  , Loss 2.3292 , Perplexity10.2702
# Epoch 0/5  , Step 2180/3236  , Loss 2.3289 , Perplexity10.2666
# Epoch 0/5  , Step 2190/3236  , Loss 2.3734 , Perplexity10.7335
# Epoch 0/5  , Step 2200/3236  , Loss 2.3743 , Perplexity10.7436
# Epoch 0/5  , Step 2210/3236  , Loss 2.3897 , Perplexity10.9105
# Epoch 0/5  , Step 2220/3236  , Loss 2.4019 , Perplexity11.0441
# Epoch 0/5  , Step 2230/3236  , Loss 2.4716 , Perplexity11.8419
# Epoch 0/5  , Step 2240/3236  , Loss 2.2209 , Perplexity9.2152
# Epoch 0/5  , Step 2250/3236  , Loss 2.2176 , Perplexity9.1854
# Epoch 0/5  , Step 2260/3236  , Loss 2.3707 , Perplexity10.7046
# Epoch 0/5  , Step 2270/3236  , Loss 2.2546 , Perplexity9.5311
# Epoch 0/5  , Step 2280/3236  , Loss 2.3132 , Perplexity10.1071
# Epoch 0/5  , Step 2290/3236  , Loss 2.4199 , Perplexity11.2450
# Epoch 0/5  , Step 2300/3236  , Loss 2.4468 , Perplexity11.5516
# Epoch 0/5  , Step 2310/3236  , Loss 2.3724 , Perplexity10.7228
# Epoch 0/5  , Step 2320/3236  , Loss 2.3949 , Perplexity10.9667
# Epoch 0/5  , Step 2330/3236  , Loss 2.4197 , Perplexity11.2427
# Epoch 0/5  , Step 2340/3236  , Loss 2.3843 , Perplexity10.8515
# Epoch 0/5  , Step 2350/3236  , Loss 2.2517 , Perplexity9.5041
# Epoch 0/5  , Step 2360/3236  , Loss 2.5426 , Perplexity12.7124
# Epoch 0/5  , Step 2370/3236  , Loss 2.1647 , Perplexity8.7116
# Epoch 0/5  , Step 2380/3236  , Loss 2.2637 , Perplexity9.6190
# Epoch 0/5  , Step 2390/3236  , Loss 2.2827 , Perplexity9.8033
# Epoch 0/5  , Step 2400/3236  , Loss 2.4255 , Perplexity11.3074
# Epoch 0/5  , Step 2410/3236  , Loss 2.3257 , Perplexity10.2336
# Epoch 0/5  , Step 2420/3236  , Loss 2.1717 , Perplexity8.7730
# Epoch 0/5  , Step 2430/3236  , Loss 2.2230 , Perplexity9.2354
